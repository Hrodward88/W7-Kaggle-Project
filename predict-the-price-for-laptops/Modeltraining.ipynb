# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


from sklearn.datasets import make_circles, make_regression

from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import r2_score as r2

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.ensemble import RandomForestClassifier as RFC

from sklearn.model_selection import GridSearchCV        # por fuerza bruta
from sklearn.model_selection import RandomizedSearchCV  # este es random

# %%
training = pd.read_csv('Filtrado.csv')

# %%
testing.head()
# Out:
#                            CPU  RAM (GB)               Storage
# 0   Intel Core i7 7500U 2.7GHz         6               1TB HDD  \
# 1  Intel Core i7 7700HQ 2.8GHz        16  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz        12             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz         4             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz         6             256GB SSD
#
#                           GPU  CPULabel  StorageLabel  GPULabel
# 0       Intel HD Graphics 620        41             6        26
# 1  Nvidia GeForce GTX 1050 Ti        43            11        39
# 2       Intel HD Graphics 620        41            19        26
# 3       Intel HD Graphics 520        27             1        22
# 4              AMD Radeon 530         2            10         4

# %%
# Out:
#                           CPU  RAM (GB)              Storage
# 0        Intel Core i5 2.3GHz         8            128GB SSD  \
# 1        Intel Core i5 1.8GHz         8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz         8            256GB SSD
# 3        Intel Core i7 2.7GHz        16            512GB SSD
# 4        Intel Core i5 3.1GHz         8            256GB SSD
#
#                             GPU  Price (Sonic Rings)  CPULabel  StorageLabel
# 0  Intel Iris Plus Graphics 640          11912523.48        59             3  \
# 1        Intel HD Graphics 6000           7993374.48        57             1
# 2         Intel HD Graphics 620           5112900.00        68            16
# 3            AMD Radeon Pro 455          22563005.40        78            28
# 4  Intel Iris Plus Graphics 650          16037611.20        61            16
#
#    GPULabel
# 0        52
# 1        46
# 2        48
# 3         8
# 4        53

# %%
training = training.drop(['CPU', 'Storage', 'GPU'], axis=1)

# %%
# Out:
#    RAM (GB)  Price (Sonic Rings)  CPULabel  StorageLabel  GPULabel
# 0         8          11912523.48        59             3        52
# 1         8           7993374.48        57             1        46
# 2         8           5112900.00        68            16        48
# 3        16          22563005.40        78            28         8
# 4         8          16037611.20        61            16        53

# %%
# Out:
#    RAM (GB)  CPULabel  StorageLabel  GPULabel
# 0         6        41             6        26
# 1        16        43            11        39
# 2        12        41            19        26
# 3         4        27             1        22
# 4         6         2            10         4

# %%
X = training.drop('Price (Sonic Rings)', axis=1)
y = training['Price (Sonic Rings)']

# %%
# Assuming 'data' is your dataset
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, random_state=42)

# %%
print (X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (781, 4) (196, 4) (781,) (196,)

# %%
X_train.head()
# Out:
#      RAM (GB)  CPULabel  StorageLabel  GPULabel
# 680         8        70            16        68
# 740         8        89             4        66
# 33         16        98            28        55
# 31          2        19            22        11
# 730        16        84             4        72

# %%
y_test.shape
# Out:
# (196,)

# %%
linear = LinearRegression()

linear.fit(X_train, y_train)

y_train_pred = linear.predict(X_train)
y_test_pred = linear.predict(X_test)

print (y_train_pred)
# Out:
# [10479457.48896981 10222971.09175305 18745330.67666148  1450903.21497836
#  16830373.0737782  11305791.4230164   3272161.72448077  6251982.04343658
#  16142758.05595821  6843847.57565319 11067828.31423987  4916376.87218317
#  10479702.68485923  4528699.63749969 10159689.26738582 10479702.68485923
#   5167474.47449143  8061554.56029052  5422414.8371323   3778199.68942991
#  13813152.80310975 13718132.32175067  9561254.18538707 10777056.016939
#  11654348.71860336 11484093.09409228  7484973.15280901 18564754.11453552
#   7157323.62540308  2882939.02286485  9893563.08358387  9128786.23271797
#   4650468.30824457 10340369.25465185  8975359.78000112  7097536.08810908
#   7539171.08413192]

# %%
train_score=linear.score(X_train, y_train)
test_score=linear.score(X_test, y_test)

print ('Train: ',train_score)
print('Test: ', test_score)
# Out:
# Train:  0.6651281857582616
# Test:  0.5265483434996318

# %%
from sklearn.metrics import mean_squared_error

train_sme = mean_squared_error(y_train, y_train_pred)
test_sme = mean_squared_error(y_test, y_test_pred)

print("SME for training set:", train_sme)
print("SME for testing set:", test_sme)
# Out:
# SME for training set: 13592042797171.273
# SME for testing set: 17117744777506.572

# %%
from sklearn.metrics import mean_absolute_error

train_mae = mean_absolute_error(y_train, y_train_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

print("MAE for training set:", train_mae)
print("MAE for testing set:", test_mae)
# Out:
# MAE for training set: 2725619.6846236293
# MAE for testing set: 2996578.6173719666

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(X_train, y_train)


y_train_pred = logistic.predict(X_train)
y_test_pred = logistic.predict(X_test)


print("Training set predictions:", y_train_pred)
print("Testing set predictions:", y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 logistic = LogisticRegression()
# ----> 4 logistic.fit(X_train, y_train)
#       7 y_train_pred = logistic.predict(X_train)
#       8 y_test_pred = logistic.predict(X_test)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1204, in LogisticRegression.fit(self, X, y, sample_weight)
#    1194     _dtype = [np.float64, np.float32]
#    1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    (...)
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
# -> 1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#    1207 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
#Let´s try PCA

Trainorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RAM (GB)             977 non-null    int64
#  1   CPULabel             977 non-null    int64
#  2   StorageLabel         977 non-null    int64
#  3   GPULabel             977 non-null    int64
#  4   Price (Sonic Rings)  977 non-null    float64
# dtypes: float64(1), int64(4)
# memory usage: 38.3 KB

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # normalizacion

from sklearn.decomposition import PCA    # PCA


data_n_mano = (Trainorder - Trainorder.mean())/Trainorder.std()

data_n = StandardScaler().fit_transform(Trainorder)

np.sum(data_n_mano - data_n)
# Out:
# RAM (GB)              -2.113587e-14
# CPULabel              -2.442491e-15
# StorageLabel          -2.142730e-14
# GPULabel               2.983724e-16
# Price (Sonic Rings)   -1.339207e-15
# dtype: float64

# %%
data_mm_mano=(Trainorder - np.min(Trainorder))/(np.max(Trainorder) - np.min(Trainorder))

data_mm=MinMaxScaler().fit_transform(Trainorder)

np.sum(data_mm_mano - data_mm)
# Out:
# RAM (GB)              -212.599864
# CPULabel              -655.827302
# StorageLabel          -404.856882
# GPULabel              -490.834174
# Price (Sonic Rings)     25.875571
# dtype: float64

# %%
TrainorderSt = StandardScaler().fit_transform(Trainorder)

# %%
pca = PCA()

pca.fit(TrainorderSt)

print(TrainorderSt.shape)

pca.explained_variance_ratio_
# Out:
# (977, 5)
# array([0.51865072, 0.21124858, 0.12566584, 0.09871006, 0.04572479])

# %%
plt.figure(figsize=(10, 5))

plt.plot(np.cumsum(pca.explained_variance_ratio_))

plt.xlabel('Numero de componentes')
plt.ylabel('% varianza')
plt.ylim([0, 1.01]);

# %%
pca = PCA(n_components=4)

Trainorder_pca=pca.fit_transform(TrainorderSt)


df=pd.DataFrame(Trainorder_pca)

df.head()
# Out:
#           0         1         2         3
# 0 -0.365685 -1.250986  0.747804  0.715709
# 1 -0.913870 -1.415763  0.887600  0.583709
# 2 -0.578597  0.013969 -0.239214 -0.074185
# 3  1.424705  2.539713  1.960882 -0.674280
# 4  0.334680  0.225533  0.149588  0.566245

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9542752109872263

# %%
pd.DataFrame(TrainorderSt).head()
# Out:
#           0         1         2         3         4
# 0 -0.105737 -0.537373 -1.596889  0.111811  0.300407
# 1 -0.105737 -0.623469 -1.852318 -0.183963 -0.321364
# 2 -0.105737 -0.149941  0.063400 -0.085372 -0.778350
# 3  1.495888  0.280539  1.595974 -2.057197  1.990101
# 4 -0.105737 -0.451277  0.063400  0.161106  0.954851

# %%
pd.DataFrame(pca.inverse_transform(df)).head()
# Out:
#           0         1         2         3         4
# 0  0.172114 -0.504752 -1.570478  0.137562 -0.020501
# 1 -0.105360 -0.623425 -1.852282 -0.183928 -0.321799
# 2 -0.432851 -0.188345  0.032306 -0.115688 -0.400544
# 3  1.837753  0.320675  1.628470 -2.025513  1.595259
# 4  0.418743 -0.389701  0.113254  0.209715  0.349094

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

from sklearn.model_selection import train_test_split as tts

from sklearn.metrics import f1_score as f1

# %%
# CON PCA

X_norm = StandardScaler().fit_transform(X)

pca = PCA(n_components=2)

X_norm = pca.fit_transform(X_norm)

X_train, X_test, y_train, y_test = tts(X_norm, y, train_size=0.8)

rfc=RFC()

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

print(X_norm.shape)
f1(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 13
#       9 X_train, X_test, y_train, y_test = tts(X_norm, y, train_size=0.8)
#      11 rfc=RFC()
# ---> 13 rfc.fit(X_train, y_train)
#      15 y_pred = rfc.predict(X_test)
#      17 print(X_norm.shape)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:385, in BaseForest.fit(self, X, y, sample_weight)
#     378         raise ValueError(
#     379             "Sum of y is not strictly positive which "
#     380             "is necessary for Poisson regression."
#     381         )
#     383 self.n_outputs_ = y.shape[1]
# --> 385 y, expanded_class_weight = self._validate_y_class_weight(y)
#     387 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     388     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# File /usr/local/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:746, in ForestClassifier._validate_y_class_weight(self, y)
#     745 def _validate_y_class_weight(self, y):
# --> 746     check_classification_targets(y)
#     748     y = np.copy(y)
#     749     expanded_class_weight = None
#
# File /usr/local/lib/python3.11/site-packages/sklearn/utils/multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'
